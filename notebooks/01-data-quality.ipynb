# %% [markdown]
# # NovaCred - Data Quality Pipeline
#
# **Role**: Data Engineer
#
# **Inputs**: `raw_credit_applications.json`
#
# **Source modules**: `__init__.py`, `clean.py`, `config.py`, `flatten.py`, `governance.py`, `io_utils.py`, `privacy.py`, `quality.py`, `schema.py`
#
# **Covers:**
#
# 1. Load and flatten
# 2. Duplicate Handling
# 3. Pre-clean Issues
# 4. Cleaning and Standardisation
# 5. Post-clean remediation evidence
# 6. Analysis Outputs
# 7. Export and checks
#
# ## Purpose
# This notebook documents the data quality assessment and remediation pipeline for NovaCred credit application data in response to a regulatory-style inquiry concerning data quality, fairness, and compliance.
#
# The workflow is designed to provide a clear and traceable line of reasoning from raw ingestion through issue identification, quantification, remediation, and preparation of analysis-ready outputs.
#
# ## Objectives
# This notebook achieves three objectives:
#
# 1. Identify and document all data quality issues.
# 2. Quantify the extent of each issue.
# 3. Demonstrate remediation steps and their impact.
#
# The core downstream outputs are retained for later analysis: `applications_analysis.csv` and `spending_items_clean.csv`.

# %%
# Setup imports and notebook configuration
from pathlib import Path
import shutil
import sys

import pandas as pd

PROJECT_ROOT = Path.cwd().resolve().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src import clean, config, flatten, io_utils, privacy, quality, schema

pd.set_option('display.max_columns', 30)
pd.set_option('display.width', 160)

# %% [markdown]
# ## Load and flatten
#
# This step establishes a controlled starting point for the assessment. By confirming the raw input structure and flattening nested records into application-level and spending-level tables, we create a consistent basis for measuring data quality and avoid ambiguity in later validation and remediation steps.

# %%
# Load raw JSON, confirm top-level list semantics, and flatten the nested records
records = io_utils.load_raw_json(config.RAW_JSON_PATH)
assert isinstance(records, list), 'Raw JSON must be a top-level list.'

print('Raw records:', len(records))
print('Redacted raw sample:')
privacy.redact_record(records[0])

applications_df = flatten.flatten_applications(records)
spending_df = flatten.flatten_spending_items(records)

print('Application rows:', len(applications_df))
print('Spending rows:', len(spending_df))
privacy.safe_preview_df(applications_df, config.DIRECT_PII_COLUMNS, n=3)
# Out:
# Raw records: 502
# Redacted raw sample:
# Application rows: 502
# Spending rows: 827
#    application_row_id application_id raw_processing_timestamp raw_applicant_full_name raw_applicant_email raw_applicant_ssn raw_applicant_ip_address  \
# 0                   0        app_200     2024-01-15T00:00:00Z         [REDACTED_NAME]    j***@hotmail.com       ***-**-4340            [REDACTED_IP]
# 1                   1        app_037                      NaN         [REDACTED_NAME]      b***@yahoo.com       ***-**-4784            [REDACTED_IP]
# 2                   2        app_215                      NaN         [REDACTED_NAME]       s***@mail.com       ***-**-5178            [REDACTED_IP]
#
#   raw_applicant_gender raw_applicant_date_of_birth raw_applicant_zip_code raw_financial_annual_income  raw_financial_annual_salary  \
# 0                 Male                  2001-**-**                  10036                       73000                          NaN
# ...

# %% [markdown]
# ## Duplicate handling
#
# Duplicate identifiers must be assessed before `application_id` can be treated as a reliable key. This step is performed to prevent record collisions from distorting issue counts, remediation decisions, and downstream analysis, while also documenting the deterministic rule used to select the canonical record.

# %%
# Classify duplicate application IDs and compute canonical analysis rows
duplicate_report_df, duplicate_metadata_df = quality.analyze_duplicate_ids(applications_df)

print('Unique application_id values:', applications_df['application_id'].nunique())
print('Duplicate application_id values:', len(duplicate_report_df))
print('Canonical rows for analysis:', int(duplicate_metadata_df['is_canonical_for_analysis'].sum()))
duplicate_report_df
# Out:
# Unique application_id values: 500
# Duplicate application_id values: 2
# Canonical rows for analysis: 500
#   application_id  dup_count classification  canonical_row_id                                   canonical_reason  \
# 0        app_001          2       conflict               455  missing_or_unparseable_timestamp_fallback_max_...
# 1        app_042          2      versioned               354  missing_or_unparseable_timestamp_fallback_max_...
#
#                                  example_differences
# 0  raw_applicant_ssn|raw_applicant_ip_address|raw...
# 1                                          raw_notes

# %% [markdown]
# ## Pre-clean issues
#
# A pre-clean assessment is required to establish the baseline condition of the data. This provides the evidence needed to quantify the extent of each issue category before any remediation is applied and ensures that later improvements can be demonstrated rather than asserted.
#
# The details of which can be found in the data_quality_report.csv

# %%
# Build the minimal rule catalog and pre-clean quality report
rule_catalog_df = schema.build_rule_catalog()

application_flags_pre = schema.validate_applications_preclean(applications_df)
spending_flags_pre = schema.validate_spending_preclean(spending_df)

pre_quality_report_df = quality.build_data_quality_report(
    applications_df=applications_df,
    application_flags=application_flags_pre,
    duplicate_report=duplicate_report_df,
    duplicate_metadata=duplicate_metadata_df,
    spending_df=spending_df,
    spending_flags=spending_flags_pre,
    stage='pre',
    rule_catalog=rule_catalog_df,
)

pre_summary_df = (
    pre_quality_report_df.groupby('issue_group', as_index=False)[['count']]
    .sum()
    .sort_values('count', ascending=False)
)
print('Pre-clean issue groups:')
pre_summary_df
# Out:
# Pre-clean issue groups:
#          issue_group  count
# 3            Privacy    497
# 0       Completeness    460
# 1        Consistency    312
# 4         Uniqueness     14
# 2  Cross-field logic     11
# 5           Validity      8

# %% [markdown]
# ## Cleaning and standardisation
#
# Cleaning is applied to reduce material quality issues without obscuring the original record. This stage is designed to improve analytical usability while preserving auditability through separate raw and clean fields and a minimal set of retained remediation indicators.
#
# The changes can be found in the before_after_comparison.csv

# %%
# Apply deterministic cleaning rules and assemble the restricted curated dataset
applications_clean_df = clean.clean_applications(applications_df)
spending_clean_df = clean.clean_spending_items(spending_df)

applications_curated_full_df = applications_clean_df.merge(
    duplicate_metadata_df,
    on=['application_row_id', 'application_id'],
    how='left',
    validate='one_to_one',
)

allowed_app_flags = {
    'gender_standardized_flag',
    'dob_parse_failed_flag',
    'dob_ambiguous_flag',
    'annual_income_from_salary_flag',
    'credit_history_nullified_flag',
    'dti_nullified_flag',
    'savings_nullified_flag',
    'approved_missing_terms_flag',
    'rejected_missing_reason_flag',
}
actual_app_flags = {column for column in applications_curated_full_df.columns if column.endswith('_flag')}
assert actual_app_flags == allowed_app_flags, f'Unexpected curated application flags: {sorted(actual_app_flags - allowed_app_flags)}'

required_duplicate_metadata = {'is_duplicate_id', 'is_canonical_for_analysis', 'has_conflict'}
assert required_duplicate_metadata.issubset(applications_curated_full_df.columns), 'Missing duplicate metadata columns in curated output.'

allowed_spending_flags = {'category_missing_flag', 'amount_invalid_flag', 'amount_negative_flag'}
actual_spending_flags = {column for column in spending_clean_df.columns if column.endswith('_flag')}
assert actual_spending_flags == allowed_spending_flags, f'Unexpected spending flags: {sorted(actual_spending_flags - allowed_spending_flags)}'

print('Restricted curated rows:', len(applications_curated_full_df))
privacy.safe_preview_df(applications_curated_full_df, config.DIRECT_PII_COLUMNS, n=3)
# Out:
# Restricted curated rows: 502
#    application_row_id application_id raw_processing_timestamp raw_applicant_full_name raw_applicant_email raw_applicant_ssn raw_applicant_ip_address  \
# 0                   0        app_200     2024-01-15T00:00:00Z         [REDACTED_NAME]    j***@hotmail.com       ***-**-4340            [REDACTED_IP]
# 1                   1        app_037                      NaN         [REDACTED_NAME]      b***@yahoo.com       ***-**-4784            [REDACTED_IP]
# 2                   2        app_215                      NaN         [REDACTED_NAME]       s***@mail.com       ***-**-5178            [REDACTED_IP]
#
#   raw_applicant_gender raw_applicant_date_of_birth raw_applicant_zip_code raw_financial_annual_income  raw_financial_annual_salary  \
# 0                 Male                  2001-**-**                  10036                       73000                          NaN
# ...

# %% [markdown]
# ## Post-clean remediation evidence
#
# Re-evaluating the cleaned outputs is necessary to show whether remediation has been effective. This stage converts cleaning from a process claim into measurable evidence by comparing pre-clean and post-clean issue levels and highlighting any residual risk that remains.

# %%
# Build the post-clean quality report and compact before-versus-after evidence table
application_flags_post = schema.validate_applications_postclean(applications_curated_full_df)
spending_flags_post = schema.validate_spending_postclean(spending_clean_df)

post_quality_report_df = quality.build_data_quality_report(
    applications_df=applications_curated_full_df,
    application_flags=application_flags_post,
    duplicate_report=duplicate_report_df,
    duplicate_metadata=duplicate_metadata_df,
    spending_df=spending_clean_df,
    spending_flags=spending_flags_post,
    stage='post',
    rule_catalog=rule_catalog_df,
)

data_quality_report_df = pd.concat([pre_quality_report_df, post_quality_report_df], ignore_index=True)

before_after_comparison_df = quality.build_before_after_comparison(
    quality_report=data_quality_report_df,
    duplicate_report=duplicate_report_df,
    duplicate_metadata=duplicate_metadata_df,
    total_records=len(applications_df),
    canonical_count=int(duplicate_metadata_df['is_canonical_for_analysis'].sum()),
)

post_summary_df = (
    post_quality_report_df.groupby('issue_group', as_index=False)[['count']]
    .sum()
    .sort_values('count', ascending=False)
)
print('Post-clean issue groups:')
post_summary_df
# Out:
# Post-clean issue groups:
#          issue_group  count
# 3            Privacy    497
# 0       Completeness    460
# 1        Consistency     44
# 4         Uniqueness     14
# 2  Cross-field logic     11
# 5           Validity      4

# %%
# Display the compact before-versus-after remediation evidence table
before_after_comparison_df.sort_values('rule_id')
# Out:
#           issue_group          rule_id                                       metric_label  pre_count  post_count  delta_count  pre_percent  post_percent  \
# 0        Completeness        R_APP_001             Missing or blank processing timestamp.        440         440            0        87.65         87.65
# 1        Completeness        R_APP_002  One or more required applicant fields missing ...          8           8            0         1.59          1.59
# 2        Completeness        R_APP_003      Both SSN and IP address are missing or blank.          5           5            0         1.00          1.00
# 3        Completeness        R_APP_004                         Email is missing or blank.          7           7            0         1.39          1.39
# 4            Validity        R_APP_005          Email does not match the expected format.          4           4            0         0.80          0.80
# ...

# %% [markdown]
# ## Analysis outputs
#
# The final cleaned outputs are retained because they support subsequent modelling and fairness assessment. This step ensures that downstream analysis is based on standardized, privacy-safe, and deduplicated data rather than on raw operational records.

# %%
# Build the PII-safe application analysis dataset, the cleaned spending dataset, and the minimal PII inventory
applications_analysis_df = privacy.build_analysis_dataset(applications_curated_full_df)
pii_inventory_df = privacy.generate_pii_inventory(
    curated_full_df=applications_curated_full_df,
    analysis_df=applications_analysis_df,
)

print('Analysis rows:', len(applications_analysis_df))
print('Analysis columns:', applications_analysis_df.columns.tolist())
privacy.safe_preview_df(applications_analysis_df, config.DIRECT_PII_COLUMNS, n=3)
# Out:
# Analysis rows: 500
# Analysis columns: ['application_id', 'applicant_pseudo_id', 'pseudo_id_source', 'pseudo_id_fallback_used_flag', 'age_band', 'age_band_missing_flag', 'clean_gender', 'clean_zip_code', 'clean_annual_income', 'clean_credit_history_months', 'clean_debt_to_income', 'clean_savings_balance', 'clean_loan_approved', 'clean_interest_rate', 'clean_approved_amount', 'clean_rejection_reason']
#   application_id                                applicant_pseudo_id pseudo_id_source  pseudo_id_fallback_used_flag age_band  age_band_missing_flag  \
# 0        app_001  fc4fb76803a008529455aa4130a4c9f4a5f72f06f7ad43...   email_fallback                          True     <NA>                   True
# 1        app_002  7fa4238022da5aed441f8c48a907a8f3cbe88186049c8e...              ssn                         False    25-34                  False
# ...

# %%
# Preview the cleaned spending analysis table with its reduced flag set
print('Spending analysis rows:', len(spending_clean_df))
print('Spending columns:', spending_clean_df.columns.tolist())
spending_clean_df.head(5)
# Out:
# Spending analysis rows: 827
# Spending columns: ['application_row_id', 'application_id', 'spending_index', 'raw_category', 'raw_amount', 'category_clean', 'category_missing_flag', 'amount_invalid_flag', 'amount_negative_flag', 'amount_clean']
#    application_row_id application_id  spending_index raw_category  raw_amount category_clean  category_missing_flag  amount_invalid_flag  \
# 0                   0        app_200               0     Shopping         480       Shopping                  False                False
# 1                   0        app_200               1         Rent         790           Rent                  False                False
# 2                   0        app_200               2      Alcohol         247        Alcohol                  False                False
# 3                   1        app_037               0         Rent         608           Rent                  False                False
# ...

# %% [markdown]
# ## Data Quality in Visualisations

# %%
import matplotlib.pyplot as plt

FIGURES_DIR = config.BASE_DIR / "figures"
FIGURES_DIR.mkdir(parents=True, exist_ok=True)

ISSUE_GROUP_COLORS = {
    "Completeness": "#4E79A7",
    "Validity": "#E15759",
    "Consistency": "#F28E2B",
    "Cross-field logic": "#59A14F",
    "Uniqueness": "#9C755F",
    "Remediation": "#76B7B2",
}

RULE_LABELS = {
    "R_APP_001": "Missing timestamp",
    "R_APP_002": "Missing applicant fields",
    "R_APP_003": "Missing SSN & IP",
    "R_APP_004": "Blank email",
    "R_APP_005": "Invalid email",
    "R_APP_006": "Gender not canonical",
    "R_APP_007": "Invalid gender",
    "R_APP_008": "DOB not ISO",
    "R_APP_009": "DOB ambiguous",
    "R_APP_010": "Income type issue",
    "R_APP_011": "Salary field drift",
    "R_APP_012": "Negative credit history",
    "R_APP_013": "Negative savings",
    "R_APP_014": "DTI out of range",
    "R_APP_015": "Missing approval terms",
    "R_APP_016": "Missing rejection reason",
    "R_APP_017": "Approved zero history",
    "R_APP_019": "Private IP address",
    "R_SPN_001": "Missing category",
    "R_SPN_002": "Invalid spending amount",
    "R_SPN_003": "Negative spending amount",
    "R_DUP_001": "Duplicate application rows",
    "R_DUP_002": "Duplicate application IDs",
    "R_DUP_003": "Repeated SSN rows",
    "R_DUP_004": "SSN cross applications",
    "R_DUP_CONFLICT": "Conflicting duplicates",
}

pre_issues_plot_df = (
    data_quality_report_df[
        (data_quality_report_df["stage"] == "pre")
        & (data_quality_report_df["issue_group"] != "Privacy")
    ]
    .copy()
)

issue_group_plot_df = (
    pre_issues_plot_df.groupby("issue_group", as_index=False)[["count", "percent"]]
    .sum()
    .sort_values("count", ascending=False)
)

rule_plot_df = pre_issues_plot_df.sort_values("count", ascending=False).copy()
rule_plot_df["short_label"] = rule_plot_df["rule_id"].map(RULE_LABELS).fillna(rule_plot_df["rule_id"])
rule_colors = rule_plot_df["issue_group"].map(ISSUE_GROUP_COLORS).fillna("#999999")

remediation_plot_df = (
    before_after_comparison_df[
        (before_after_comparison_df["issue_group"] != "Privacy")
        & (before_after_comparison_df["rule_id"] != "R_DUP_CANONICAL")
        & (before_after_comparison_df["pre_count"] != before_after_comparison_df["post_count"])
    ]
    .copy()
)

fig, ax = plt.subplots(figsize=(8, 5))
bars = ax.bar(issue_group_plot_df["issue_group"], issue_group_plot_df["count"], color=issue_group_plot_df["issue_group"].map(ISSUE_GROUP_COLORS))
ax.set_title("Issues Found by Issue Group (Pre-clean)")
ax.set_xlabel("Issue Group")
ax.set_ylabel("Issue Count")
ax.spines[["top", "right"]].set_visible(False)
plt.xticks(rotation=25, ha="right")
for bar, pct in zip(bars, issue_group_plot_df["percent"]):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f"{int(bar.get_height())} ({pct:.2f}%)", ha="center", va="bottom")
plt.tight_layout()
fig.savefig(FIGURES_DIR / "fig_data_quality_issue_groups.png", bbox_inches="tight")
plt.show()

fig, ax = plt.subplots(figsize=(12, 8))
bars = ax.barh(rule_plot_df["short_label"], rule_plot_df["count"], color=rule_colors)
ax.set_title("Issues Found by Rule (Pre-clean)")
ax.set_xlabel("Issue Count")
ax.set_ylabel("Rule ID")
ax.spines[["top", "right"]].set_visible(False)
for bar, pct in zip(bars, rule_plot_df["percent"]):
    ax.text(bar.get_width(), bar.get_y() + bar.get_height() / 2, f" {int(bar.get_width())} ({pct:.2f}%)", va="center", fontsize=9)
ax.invert_yaxis()
legend_handles = [
    plt.Rectangle((0, 0), 1, 1, color=color, label=group)
    for group, color in ISSUE_GROUP_COLORS.items()
    if group in rule_plot_df["issue_group"].unique()
]
ax.legend(handles=legend_handles, title="Issue Group")
plt.tight_layout()
fig.savefig(FIGURES_DIR / "fig_data_quality_rules.png", bbox_inches="tight")
plt.show()

remediation_plot_df["improvement_count"] = remediation_plot_df["pre_count"] - remediation_plot_df["post_count"]
remediation_plot_df["improvement_percent"] = remediation_plot_df["pre_percent"] - remediation_plot_df["post_percent"]
remediation_plot_df["abs_improvement_count"] = remediation_plot_df["improvement_count"].abs()
remediation_plot_df["short_label"] = remediation_plot_df["rule_id"].map(RULE_LABELS).fillna(remediation_plot_df["rule_id"])
remediation_plot_df = remediation_plot_df.sort_values("abs_improvement_count", ascending=False).copy()

fig, ax = plt.subplots(figsize=(12, 6))
y_pos = range(len(remediation_plot_df))

for y, pre_count, post_count in zip(y_pos, remediation_plot_df["pre_count"], remediation_plot_df["post_count"]):
    ax.plot([post_count, pre_count], [y, y], color="#B0B0B0", linewidth=2)

ax.scatter(remediation_plot_df["pre_count"], y_pos, color="#E15759", s=70, label="Pre", zorder=3)
ax.scatter(remediation_plot_df["post_count"], y_pos, color="#59A14F", s=70, label="Post", zorder=3)
ax.set_yticks(list(y_pos))
ax.set_yticklabels(remediation_plot_df["short_label"])
ax.invert_yaxis()
ax.set_title("Remediation Improvement: Pre vs Post", loc="left")
ax.set_xlabel("Issue Count")
ax.set_ylabel("Rule ID")
ax.legend(loc="lower right")
ax.set_xlim(left=0)
ax.spines[["top", "right"]].set_visible(False)
for y, pre_count, post_count, pct in zip(y_pos, remediation_plot_df["pre_count"], remediation_plot_df["post_count"], remediation_plot_df["improvement_percent"]):
    ax.text(pre_count + 1, y + 0.12, f"Pre: {pre_count}", va="center", color="#E15759", fontsize=9)
    ax.text(post_count + 1, y - 0.12, f"Post: {post_count}", va="center", color="#59A14F", fontsize=9)
    mid_x = (pre_count + post_count) / 2
    ax.text(mid_x, y - 0.22, f"{pct:+.2f}%", ha="center", va="center", fontsize=9)
plt.tight_layout()
fig.savefig(FIGURES_DIR / "fig_data_quality_remediation_dumbbell.png", bbox_inches="tight")
plt.show()
